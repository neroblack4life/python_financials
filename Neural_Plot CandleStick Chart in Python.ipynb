# %% [markdown]
# import datetime as dt
# import matplotlib.dates as mdates
# import matplotlib.pyplot as plt
# import pandas_datareader as web
# from mpl_finance import candlestick_ohlc
#
# start = dt.datetime(2015,1,1)
# end = dt.datetime.now()
#
# df = web.DataReader('AAPL','yahoo',start, end)
#
# print(df.head())
#
# df = df[['Open','High','Low','Close']]
#
# df.reset_index(inplace=True)
# df['Date'] = df['Date'].map(mdates.date2num)
#
# ax = plt.subplot()
# candlestick_ohlc(ax, df.values, width=8, colorup='g', colordown='r')
# ax.xaxis_date()
# ax.grid(True)
# plt.show()
#
# ax.grid(True)
# ax.set_axisbelow(True)
# ax.set_title('AAPL Share Price', color='white')
# ax.set_facecolor('black')
# ax.figure.set_facecolor('#121212')
# ax.tick_params(axis='x', colors='white')
# ax.tick_params(axis='y', colors='white')
# ax.xaxis_date()

# %%
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import pandas_datareader as web
from mpl_finance import candlestick_ohlc

start = dt.datetime(2000,1,1)
end = dt.datetime.now()

df = web.DataReader('NZDUSD=X','yahoo',start, end)

print(df.head())

df = df[['Open','High','Low','Close']]

df.reset_index(inplace=True)
df['Date'] = df['Date'].map(mdates.date2num)

ax = plt.subplot()
candlestick_ohlc(ax, df.values, width=8, colorup='g', colordown='r')
ax.xaxis_date()
ax.grid(True)
plt.show()
# Out:
#                 High       Low      Open     Close  Volume  Adj Close
# Date
# 2003-12-01  0.643087  0.640985  0.641190  0.644288     0.0   0.644288
# 2003-12-02  0.643998  0.643418  0.643791  0.646204     0.0   0.646204
# 2003-12-03  0.649815  0.647207  0.647417  0.649519     0.0   0.649519
# 2003-12-04  0.647585  0.645120  0.645120  0.645911     0.0   0.645911
# 2003-12-05  0.645411  0.644081  0.645411  0.645120     0.0   0.645120

# %%
pip install datetime
# Out:
# Collecting datetime
#   Downloading DateTime-4.3-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 3.3 MB/s eta 0:00:011
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: pytz in /srv/conda/envs/notebook/lib/python3.7/site-packages (from datetime) (2021.1)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from zope.interface->datetime) (49.6.0.post20210108)
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-4.3 zope.interface-5.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 4.6 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.1)
# Collecting numpy>=1.16.5
#   Downloading numpy-1.20.2-cp37-cp37m-manylinux2010_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 71.1 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.20.2 pandas-1.2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.9.0-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 4.4 MB/s eta 0:00:01
# Collecting lxml
#   Downloading lxml-4.6.3-cp37-cp37m-manylinux1_x86_64.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 7.6 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas_datareader) (1.2.4)
# Requirement already satisfied: requests>=2.19.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas_datareader) (2.25.1)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.23->pandas_datareader) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.23->pandas_datareader) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.19.0->pandas_datareader) (1.26.3)
# Installing collected packages: lxml, pandas-datareader
# Successfully installed lxml-4.6.3 pandas-datareader-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mpl_finance
# Out:
# Collecting mpl_finance
#   Downloading mpl_finance-0.10.1-py3-none-any.whl (8.4 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib->mpl_finance) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib->mpl_finance) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib->mpl_finance) (2.4.7)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 72.2 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 41.7 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->mpl_finance) (1.15.0)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib, mpl-finance
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.1 mpl-finance-0.10.1 pillow-8.2.0
# Note: you may need to restart the kernel to use updated packages.
